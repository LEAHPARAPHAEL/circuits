# %%
from ploting_utils import plot_minimality_results

# Define categories for heads
head_categories = {
    "Name Mover Heads": [(9, 9), (10, 0), (9, 6)],
    "Negative Heads": [(10, 7), (11, 10)],
    "S-Inhibition Heads": [(7, 3), (7, 9), (8, 6), (8, 10)],
    "Induction Heads": [(5, 5),(5,8),(5,9),(6,9)],
    "Duplicate token Heads": [(0,1),(0,10),(3,0)],
    "Previous token": [(2,2),(2,9),(4,11)],
    "Backup name mover": [(10, 10), (10, 2), (11, 2), (10, 6),(10,1),(9,7),(11,9),(11,3)],
}

custom_order = [
    (9, 9), (10, 0), (9, 6),
    (10, 7), (11, 10),
      (8, 6), (7, 9),(8, 10),(7, 3),
    (5, 5),(6,9),(5,9),(5,8),
    (0,1),(0,10),(3,0),
    (4,11),(2,2),(2,9),
    (11, 2), (10, 10), (10, 2),  (10, 6),(10,1),(9,7),(11,9),(11,3)
]


# Plot with custom order and categories
plot_minimality_results(
    results_file='results/minimality/minimality_BABA_T=0.json',
    categories=head_categories,
    no_abs_value = True,
    template_key_list = [0],
    order=custom_order,
    save_path = "plots/minimality_BABA_T0_signed_difference.png"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      14 custom_order = [
#      15     (9, 9), (10, 0), (9, 6),
#      16     (10, 7), (11, 10),
#    (...)     21     (11, 2), (10, 10), (10, 2),  (10, 6),(10,1),(9,7),(11,9),(11,3)
#      22 ]
#      25 # Plot with custom order and categories
# ---> 26 plot_minimality_results(
#      27     results_file='results/minimality/minimality_BABA_T=0.json',
#      28     categories=head_categories,
#      29     no_abs_value = True,
#      30     order=custom_order,
#      31     save_path = "plots/minimality_BABA_T0_signed_difference.png"
#      32 )
#
# File ~/circuits/ploting_utils.py:135, in plot_minimality_results(results_file, categories, no_abs_value, figsize, order, save_path)
#     132     ax.legend(handles=legend_elements, loc='best', framealpha=0.9)
#     134 plt.tight_layout()
# --> 135 if plot_title:
# ...
